# %%
import sys
import os

# # Add the project root (one level up from "tests") to Python’s import path
sys.path.append(os.path.abspath(os.path.join(os.path.dirname(__file__), "..")))

from PyPDF2 import PdfReader
from pathlib import Path
from typing import List
from PyPDF2 import PdfWriter

from config import config

def get_pages(file_path : Path, page_numbers : List = [0]) -> bool:
    reader = PdfReader(file_path)
    writer = PdfWriter()
    try:
        for page_num in page_numbers:
            writer.add_page(reader.pages[page_num])
            
        output_path = config.ESSENTIALS_DIR / f"{file_path.name}"
        
        with open(output_path, "wb") as shortened_pdf:
            writer.write(shortened_pdf)
        
        return True
    
    except Exception as e:
        print(f"Error creating shortened PDF: {str(e)}")
        return False

test_paper = config.TRAINING_DIR / "pdf_1.pdf"

print(get_pages(test_paper))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 5
#       2 import os
#       4 # # Add the project root (one level up from "tests") to Python’s import path
# ----> 5 sys.path.append(os.path.abspath(os.path.join(os.path.dirname(__file__), "..")))
#       7 from PyPDF2 import PdfReader
#       8 from pathlib import Path
#
# NameError: name '__file__' is not defined

# %%
# !pip install pypdf2
# Out:
# Requirement already satisfied: pypdf2 in /opt/homebrew/lib/python3.10/site-packages (3.0.1)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: /opt/homebrew/opt/python@3.10/bin/python3.10 -m pip install --upgrade pip
